# %%
import nltk
#Data Preprocessing Package
import re
import numpy as np
import pandas as pd
import os
import nltk
from nltk.tokenize import TreebankWordTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.tag import pos_tag

from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS as sklearn_stop_words
import re
import nltk
#from nltk.tokenize import TreebankWordTokenizer
from nltk.tokenize import WordPunctTokenizer 
from nltk.stem import WordNetLemmatizer
from nltk.tag import pos_tag

from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS as sklearn_stop_words
import re
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS as sklearn_stop_words
from nltk.tag import pos_tag
lemma = WordNetLemmatizer()

# %%
df=pd.DataFrame(columns=['filelist','rawdata'])

# %%
directory = './Data/subtext/'
filelist = os.listdir(directory)
df['filelist']=filelist

# %%
for i in range(len(df)):
    j = df['filelist'][i]
    filename = directory + j
    f=open(filename, 'r', encoding='utf-8')
    txt = f.read()
    f.close()
    df['rawdata'][i] = txt

df
# Out:
#                                    filelist  \
# 0              1.samsung_electronic2021.txt
# 1   101.Hyosung_Advanced_Materials_2020.txt
# 2                 103.meritz securities.txt
# 3                               106.OCI.txt
# 4                        107.skchemical.txt
# ..                                      ...
# 92                           9.hmc-2021.txt
# 93                     90.samsung_heavy.txt
# 94                            92.gs_e_c.txt
# 95                      94.cj_logistics.txt
# 96                        99.hanmipharm.txt
#
#                                               rawdata
# 0   Samsung Electronics Sustainability Report 2021...
# 1   Sustainability\n\nwith Stakeholders\n2020 Hyos...
# 2   2019 SUSTAINABILITY REPORT \nMORE  \nTHAN JUST...
# 3   INTEGRATED REPORT 2020  \nTRANSFORMING OPPORTU...
# 4   2020 SK chemicals Sustainability Report\nWe Ca...
# ..                                                ...
# 92  Road to \nSustainability 2021 Sustainability R...
# 93  SAMSUNG HEAVY INDUSTRIES  SUSTAINABILITY REPOR...
# 94  Grow with  \nGreen Sustainability GS E&C Integ...
# 95  ABOUT THIS REPORT\nSummary \nCJ Logistics has ...
# 96  02 Introduction · Contents 03 2020-21 CSR Repo...
#
# [97 rows x 2 columns]

# %%
df['filein']=df.filelist

for i in range(len(df)):
    df.filein[i] = df.filein[i][:3]
    df.filein[i] = re.sub('[.]','',df.filein[i])
    df.filein[i] = re.sub('[A-z]','',df.filein[i])
df
# Out:
#                                    filelist  \
# 0              1.samsung_electronic2021.txt
# 1   101.Hyosung_Advanced_Materials_2020.txt
# 2                 103.meritz securities.txt
# 3                               106.OCI.txt
# 4                        107.skchemical.txt
# ..                                      ...
# 92                           9.hmc-2021.txt
# 93                     90.samsung_heavy.txt
# 94                            92.gs_e_c.txt
# 95                      94.cj_logistics.txt
# 96                        99.hanmipharm.txt
#
#                                               rawdata filein
# 0   Samsung Electronics Sustainability Report 2021...      1
# 1   Sustainability\n\nwith Stakeholders\n2020 Hyos...    101
# 2   2019 SUSTAINABILITY REPORT \nMORE  \nTHAN JUST...    103
# 3   INTEGRATED REPORT 2020  \nTRANSFORMING OPPORTU...    106
# 4   2020 SK chemicals Sustainability Report\nWe Ca...    107
# ..                                                ...    ...
# 92  Road to \nSustainability 2021 Sustainability R...      9
# 93  SAMSUNG HEAVY INDUSTRIES  SUSTAINABILITY REPOR...     90
# 94  Grow with  \nGreen Sustainability GS E&C Integ...     92
# 95  ABOUT THIS REPORT\nSummary \nCJ Logistics has ...     94
# 96  02 Introduction · Contents 03 2020-21 CSR Repo...     99
#
# [97 rows x 3 columns]

# %%
for i in range(len(df)):
    if len(df.filein[i]) == 1 :
        df.filein[i] = '00' + df.filein[i]
    if len(df.filein[i]) == 2 :
        df.filein[i] = '0' + df.filein[i]  
df =df.sort_values('filein')
df
# Out:
#                         filelist  \
# 0   1.samsung_electronic2021.txt
# 35            2.sk_hynix2021.txt
# 48              3.NAVER_2020.txt
# 62  4.Samsung_Biologics_2021.txt
# 77              6.KAKAO_2020.txt
# ..                           ...
# 45       274.HyundaiElectric.txt
# 47             291.NEXENTIRE.txt
# 51              310.Pulmuone.txt
# 55            341_sknetworks.txt
# 57        359_Halla Holdings.txt
#
#                                               rawdata filein
# 0   Samsung Electronics Sustainability Report 2021...    001
# 35  We Do Technology SK hynix Sustainability Repor...    002
# 48  @@@\nEmbracing  \nSustainability for  Growth\n...    003
# 62  @@@\nSustainability  Report  \n2021\nAbout Thi...    004
# 77  2020 \nKakao's \nCommitment and  Responsibilit...    006
# ..                                                ...    ...
# 45  HYUNDAI 2021 ELECTRIC &  \nENERGY SYSTEMS \nIN...    274
# 47  2020/21 NEXEN TIRE ESG REPORT\nNext Level Mobi...    291
# 51  Pulmuone \nIntegrated Report \nAbout this Repo...    310
# 55  SK NETWORKS SUSTAINABILITY REPORT 2019 \nWE NE...    341
# 57  2020 \nHalla Holdings Sustainability Report\nR...    359
#
# [97 rows x 3 columns]

# %%
df= df.set_index('filein')
df= df.set_index('filelist')
df
# Out:
#                                                                         rawdata
# filelist
# 1.samsung_electronic2021.txt  Samsung Electronics Sustainability Report 2021...
# 2.sk_hynix2021.txt            We Do Technology SK hynix Sustainability Repor...
# 3.NAVER_2020.txt              @@@\nEmbracing  \nSustainability for  Growth\n...
# 4.Samsung_Biologics_2021.txt  @@@\nSustainability  Report  \n2021\nAbout Thi...
# 6.KAKAO_2020.txt              2020 \nKakao's \nCommitment and  Responsibilit...
# ...                                                                         ...
# 274.HyundaiElectric.txt       HYUNDAI 2021 ELECTRIC &  \nENERGY SYSTEMS \nIN...
# 291.NEXENTIRE.txt             2020/21 NEXEN TIRE ESG REPORT\nNext Level Mobi...
# 310.Pulmuone.txt              Pulmuone \nIntegrated Report \nAbout this Repo...
# 341_sknetworks.txt            SK NETWORKS SUSTAINABILITY REPORT 2019 \nWE NE...
# 359_Halla Holdings.txt        2020 \nHalla Holdings Sustainability Report\nR...
#
# [97 rows x 1 columns]

# %%
sub=[]
for i in df.rawdata : 
    sub.append(i.split('@@@'))
df['sub'] = sub
df
# Out:
#                                                                         rawdata  \
# filelist
# 1.samsung_electronic2021.txt  Samsung Electronics Sustainability Report 2021...
# 2.sk_hynix2021.txt            We Do Technology SK hynix Sustainability Repor...
# 3.NAVER_2020.txt              @@@\nEmbracing  \nSustainability for  Growth\n...
# 4.Samsung_Biologics_2021.txt  @@@\nSustainability  Report  \n2021\nAbout Thi...
# 6.KAKAO_2020.txt              2020 \nKakao's \nCommitment and  Responsibilit...
# ...                                                                         ...
# 274.HyundaiElectric.txt       HYUNDAI 2021 ELECTRIC &  \nENERGY SYSTEMS \nIN...
# 291.NEXENTIRE.txt             2020/21 NEXEN TIRE ESG REPORT\nNext Level Mobi...
# 310.Pulmuone.txt              Pulmuone \nIntegrated Report \nAbout this Repo...
# 341_sknetworks.txt            SK NETWORKS SUSTAINABILITY REPORT 2019 \nWE NE...
# 359_Halla Holdings.txt        2020 \nHalla Holdings Sustainability Report\nR...
#
#                                                                             sub
# filelist
# 1.samsung_electronic2021.txt  [Samsung Electronics Sustainability Report 202...
# 2.sk_hynix2021.txt            [We Do Technology SK hynix Sustainability Repo...
# 3.NAVER_2020.txt              [, \nEmbracing  \nSustainability for  Growth\n...
# 4.Samsung_Biologics_2021.txt  [, \nSustainability  Report  \n2021\nAbout Thi...
# 6.KAKAO_2020.txt              [2020 \nKakao's \nCommitment and  Responsibili...
# ...                                                                         ...
# 274.HyundaiElectric.txt       [HYUNDAI 2021 ELECTRIC &  \nENERGY SYSTEMS \nI...
# 291.NEXENTIRE.txt             [2020/21 NEXEN TIRE ESG REPORT\nNext Level Mob...
# 310.Pulmuone.txt              [Pulmuone \nIntegrated Report \nAbout this Rep...
# 341_sknetworks.txt            [SK NETWORKS SUSTAINABILITY REPORT 2019 \nWE N...
# 359_Halla Holdings.txt        [2020 \nHalla Holdings Sustainability Report\n...
#
# [97 rows x 2 columns]

# %%
df.sub
# Out:
# <bound method flex_arith_method_FRAME.<locals>.f of                                                                         rawdata  \
# filelist
# 1.samsung_electronic2021.txt  Samsung Electronics Sustainability Report 2021...
# 2.sk_hynix2021.txt            We Do Technology SK hynix Sustainability Repor...
# 3.NAVER_2020.txt              @@@\nEmbracing  \nSustainability for  Growth\n...
# 4.Samsung_Biologics_2021.txt  @@@\nSustainability  Report  \n2021\nAbout Thi...
# 6.KAKAO_2020.txt              2020 \nKakao's \nCommitment and  Responsibilit...
# ...                                                                         ...
# 274.HyundaiElectric.txt       HYUNDAI 2021 ELECTRIC &  \nENERGY SYSTEMS \nIN...
# 291.NEXENTIRE.txt             2020/21 NEXEN TIRE ESG REPORT\nNext Level Mobi...
# 310.Pulmuone.txt              Pulmuone \nIntegrated Report \nAbout this Repo...
# 341_sknetworks.txt            SK NETWORKS SUSTAINABILITY REPORT 2019 \nWE NE...
# 359_Halla Holdings.txt        2020 \nHalla Holdings Sustainability Report\nR...
#
#                                                                             sub
# filelist
# 1.samsung_electronic2021.txt  [Samsung Electronics Sustainability Report 202...
# 2.sk_hynix2021.txt            [We Do Technology SK hynix Sustainability Repo...
# 3.NAVER_2020.txt              [, \nEmbracing  \nSustainability for  Growth\n...
# 4.Samsung_Biologics_2021.txt  [, \nSustainability  Report  \n2021\nAbout Thi...
# 6.KAKAO_2020.txt              [2020 \nKakao's \nCommitment and  Responsibili...
# ...                                                                         ...
# 274.HyundaiElectric.txt       [HYUNDAI 2021 ELECTRIC &  \nENERGY SYSTEMS \nI...
# 291.NEXENTIRE.txt             [2020/21 NEXEN TIRE ESG REPORT\nNext Level Mob...
# 310.Pulmuone.txt              [Pulmuone \nIntegrated Report \nAbout this Rep...
# 341_sknetworks.txt            [SK NETWORKS SUSTAINABILITY REPORT 2019 \nWE N...
# 359_Halla Holdings.txt        [2020 \nHalla Holdings Sustainability Report\n...
#
# [97 rows x 2 columns]>

# %%
len(df['sub'][0])
# Out:
# 49
